# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6
# ---
# Normal text. to initiate a new paragraph you need a new blank line,
# an enter does not make a break
#
# like this, a new blank line makes a new paragraph
#
# # Text Styling
#
# ## Bold and Italic
#
# ### Bold
# **This is bold text**
# __This is also bold text__
#
# ### Italic
# *This is italicized text*
# _This is also italicized text_
#
# ### Italic and Bold
# ***This is italicized and bold text***
#
# ### Partially Bold or italic
# This is i*talicized* text and B**ol**d ***text***
#
# ## Strikethrough
#
# ~~this is cancelled~~
#
# ## Highlighted
#
# <mark>Highlighted part</mark>
#
# ## Sub/Sup script
#
# X<sub>1</sub>>X<sub>2</sub>
#
# y=X<sup>2</sup>
# ---
# # **Handling Code**
# ## Inline Code
# *To diplay code inline you can wrap your code in a single "`" character. This is useful for displaying small snippets of code within a paragraph.*
# This is `inline code` within a paragraph.
# ## Code Blocks
# ***Three "`" characters*** *can be used to display a larger block*
# This text is followed by a block:
# ```r
# # This is an r code block.
# x == 1
# ```
# ---
# # Other Elements
# ## Links
#
# [This is a link](https://www.baidu.com)
#
# [Relative link](/images/Actions-to-step-4.png)
#
# https://www.google.com
#
# ## Images
#
# ![The Google Logo](/images/Actions-to-step-4.png)
#
# ## Blockquotes
# >This is a blockquote
# >>This is a nested blockquote
# >>>And a secondary nested blockquote
#
# ## Horizontal Rule
# ***
# ---
# ___
#
# ## Tables
#
# |Name|Sex|Age|
# |----|---|---|
# |Mark|Male|30|
# |Does not have to be algned!|
#
# ## Checklist
#
# *use "- [ ]" or "- [x]" to illustrate something checked or not checked*
# - [ ] Tomaten
# - [ ] Kartoffeln
# - [x] Eis
# - [ ] Unchecked
# - [x] Checked
